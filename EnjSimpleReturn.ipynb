# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
enjUsd = wb.DataReader('ENJ-USD', data_source='yahoo', start='2020-2-1', end='2021-1-1')

# %%
enjUsd.head(20)
# Out:
#                 High       Low      Open     Close      Volume  Adj Close
# Date
# 2020-02-01  0.105451  0.093840  0.094353  0.103426  10295891.0   0.103426
# 2020-02-02  0.114298  0.097921  0.103257  0.112388  15360586.0   0.112388
# 2020-02-03  0.116026  0.107105  0.112388  0.114464  16063690.0   0.114464
# 2020-02-04  0.153087  0.112442  0.114516  0.149385  75767242.0   0.149385
# 2020-02-05  0.164875  0.125792  0.149576  0.136190  52312985.0   0.136190
# 2020-02-06  0.142258  0.130468  0.136080  0.137833  24795454.0   0.137833
# 2020-02-07  0.141597  0.127596  0.137891  0.131606  14681487.0   0.131606
# 2020-02-08  0.135014  0.121338  0.131552  0.128086  12618822.0   0.128086
# 2020-02-09  0.138562  0.121776  0.127973  0.133299  18626808.0   0.133299
# 2020-02-10  0.141117  0.127458  0.133327  0.140160  16457682.0   0.140160
# 2020-02-11  0.140487  0.133243  0.140402  0.138280  11668784.0   0.138280
# 2020-02-12  0.147206  0.137598  0.138199  0.142261  17281104.0   0.142261
# ...

# %%
enjUsd.tail(20)
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 2020-10-05  0.155999  0.148702  0.152857  0.155158  6636838.0   0.155158
# 2020-10-06  0.155786  0.143182  0.155099  0.144178  6566253.0   0.144178
# 2020-10-07  0.149132  0.140016  0.144178  0.149132  6264223.0   0.149132
# 2020-10-08  0.152033  0.142273  0.149110  0.150244  8169426.0   0.150244
# 2020-10-10  0.163858  0.154455  0.154499  0.159945  8654502.0   0.159945
# 2020-10-11  0.165961  0.156709  0.159858  0.159088  7731171.0   0.159088
# 2020-10-14  0.162637  0.150524  0.161602  0.154171  7784638.0   0.154171
# 2020-10-15  0.155821  0.150010  0.154140  0.152803  5399069.0   0.152803
# 2020-10-16  0.153328  0.144765  0.152895  0.145748  6142036.0   0.145748
# 2020-10-17  0.150826  0.145018  0.145955  0.148693  3724772.0   0.148693
# 2020-10-18  0.151012  0.147610  0.148887  0.150821  2766776.0   0.150821
# 2020-10-19  0.151269  0.147247  0.150840  0.149535  4823926.0   0.149535
# ...

# %%
enjUsd['simple_return'] = (enjUsd['Adj Close'] / enjUsd['Adj Close'].shift(1)) - 1
print(enjUsd['simple_return'])
# Out:
# Date
# 2020-02-01         NaN
# 2020-02-02    0.086651
# 2020-02-03    0.018472
# 2020-02-04    0.305083
# 2020-02-05   -0.088329
#                 ...
# 2020-10-23   -0.021987
# 2020-10-24   -0.007374
# 2020-10-25   -0.017075
# 2020-10-26   -0.038789
# 2020-10-27    0.000845
# Name: simple_return, Length: 266, dtype: float64

# %%
enjUsd['simple_return'] = (enjUsd['Adj Close'] / enjUsd['Adj Close'].shift(1)) - 1
enjUsd['simple_return']
# Out:
# Date
# 2020-02-01         NaN
# 2020-02-02    0.086651
# 2020-02-03    0.018472
# 2020-02-04    0.305083
# 2020-02-05   -0.088329
#                 ...
# 2020-10-23   -0.021987
# 2020-10-24   -0.007374
# 2020-10-25   -0.017075
# 2020-10-26   -0.038789
# 2020-10-27    0.000845
# Name: simple_return, Length: 266, dtype: float64

# %%
enjUsd['simple_return'].plot(figsize=(10,5))
plt.show()

# %%
avg_returns_day = enjUsd['simple_return'].mean()
avg_returns_day
# Out:
# 0.0034062880444400276

# %%
avg_returns_a = enjUsd['simple_return'].mean() * 250
avg_returns_a
# Out:
# 0.8515720111100069

# %%
print(str(round(avg_returns_a,4) * 100) + '%')
# Out:
# 85.16%
